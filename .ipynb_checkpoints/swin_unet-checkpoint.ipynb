# %%
from glob import glob
import numpy as np
from sklearn.model_selection import train_test_split
import cv2
import torch
import torch.nn as nn
import torch.nn.functional
import torchvision
from torch.utils.data import TensorDataset
import math

# %%
def load_image(path, size):
    image = cv2.imread(path)
    image = cv2.resize(image, (size,size))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    image = image/255.
    return image

def load_data(root_path, size):
    images = []
    masks = []
    x = 0
    for path in sorted(glob(root_path)):
        img = load_image(path, size)
        if 'mask' in path:
            if x:
                masks[-1] += img
                masks[-1] = np.array(masks[-1]>0.5, dtype='float64')
            else:
                masks.append(img)
                x = 1
        else:
            images.append(img)
            x = 0
    return np.array(images), np.array(masks)

# %% [markdown]
# ## Loading image and mask data

# %%
import cv2
import numpy as np
from glob import glob
import os

def load_image(path, size):
    image = cv2.imread(path)
    image = cv2.resize(image, (size, size))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    image = image / 255.0
    return image

def load_data(image_folder, mask_folder, size):
    images = []
    masks = []
    
    # Get sorted file lists
    image_paths = sorted(glob(os.path.join(image_folder, '*')))
    mask_paths = sorted(glob(os.path.join(mask_folder, '*')))
    
    for img_path, mask_path in zip(image_paths, mask_paths):
        # Load image
        img = load_image(img_path, size)
        images.append(img)
        
        # Load mask
        mask = load_image(mask_path, size)
        masks.append(mask)
    
    return np.array(images), np.array(masks)

# %%
image_path = "Your designated Image path"
masks_path = "Your designated mask path"

size = 224
X, Y = load_data(image_path, masks_path, size)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, shuffle=True)
X_valid, X_test, Y_valid, Y_test = train_test_split(X_test, Y_test, test_size=0.5,shuffle=True)
X_train.shape, X_valid.shape, X_test.shape, Y_train.shape, Y_valid.shape, Y_test.shape
# Out:
# ((5474, 224, 224),
#  (1173, 224, 224),
#  (1173, 224, 224),
#  (5474, 224, 224),
#  (1173, 224, 224),
#  (1173, 224, 224))

# %%
X_train = np.expand_dims(X_train,-1)
Y_train = np.expand_dims(Y_train,-1)

def elastic_transform(image, mask, alpha_affine):

    random_state = np.random.RandomState(None)
    shape = image.shape
    shape_size = shape[:2]

    # Random affine
    center_square = np.float32(shape_size) // 2
    square_size = 42#min(shape_size) // 3
    pts1 = np.float32([center_square + square_size, [center_square[0]+square_size, center_square[1]-square_size], center_square - square_size])
    pts2 = pts1 + random_state.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
    M = cv2.getAffineTransform(pts1, pts2)
    image = cv2.warpAffine(image, M, shape_size[::-1], borderMode=cv2.BORDER_REFLECT_101)
    mask = cv2.warpAffine(mask, M, shape_size[::-1], borderMode=cv2.BORDER_REFLECT_101)
    return image, mask

def hflip_transform(image, mask):
    image = cv2.flip(image, 1)
    mask = cv2.flip(mask, 1)
    return image, mask

def vflip_transform(image, mask):
    image = cv2.flip(image, 0)
    mask = cv2.flip(mask, 0)
    return image, mask

def flip_transform(image, mask):
    image = cv2.flip(image, -1)
    mask = cv2.flip(mask, -1)
    return image, mask

el_train_images = [elastic_transform(img, mask, img.shape[1] * 0.04) for img,mask in zip(X_train,Y_train )]

hflip_train_images = [hflip_transform(img, mask) for img,mask in zip(X_train,Y_train )]

vflip_train_images = [vflip_transform(img, mask) for img,mask in zip(X_train,Y_train )]

flip_train_images = [flip_transform(img, mask) for img,mask in zip(X_train,Y_train )]


train_images_list = [el_train_images, hflip_train_images, vflip_train_images, flip_train_images]


for each_el_tf in train_images_list:
    el_tf_imgs,  el_tf_masks = zip(*each_el_tf)
    el_tf_imgs = list(el_tf_imgs)
    el_tf_masks = list(el_tf_masks)
    X_train = np.concatenate((X_train, np.expand_dims(el_tf_imgs, -1)))
    Y_train = np.concatenate((Y_train, np.expand_dims(el_tf_masks, -1)))

X_train = torch.from_numpy(np.float32(np.squeeze(X_train,-1))).unsqueeze(1)
Y_train = torch.from_numpy(np.float32(np.squeeze(Y_train,-1))).unsqueeze(1)
X_valid = torch.from_numpy(np.float32(X_valid)).unsqueeze(1)
Y_valid = torch.from_numpy(np.float32(Y_valid)).unsqueeze(1)
X_test = torch.from_numpy(np.float32(X_test)).unsqueeze(1)
Y_test = torch.from_numpy(np.float32(Y_test)).unsqueeze(1)
X_train.shape, X_valid.shape, X_test.shape, Y_train.shape, Y_valid.shape, Y_test.shape
# Out:
# (torch.Size([27370, 1, 224, 224]),
#  torch.Size([1173, 1, 224, 224]),
#  torch.Size([1173, 1, 224, 224]),
#  torch.Size([27370, 1, 224, 224]),
#  torch.Size([1173, 1, 224, 224]),
#  torch.Size([1173, 1, 224, 224]))

# %%
BATCH_SIZE = 32

train_loader = torch.utils.data.DataLoader(TensorDataset(X_train,Y_train), batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_loader = torch.utils.data.DataLoader(TensorDataset(X_valid,Y_valid), batch_size=BATCH_SIZE,
                                        shuffle=True)

test_loader = torch.utils.data.DataLoader(TensorDataset(X_test,Y_test), batch_size=BATCH_SIZE,
                                        shuffle=True)

# %%
def window_partition(x, window_size):
    B, H, W, C = x.shape
    x = x.view(B, H // window_size[0], window_size[0], W // window_size[1], window_size[1], C)
    windows = x.permute(0, 1, 3, 2, 4, 5).contiguous().view(-1, window_size[0], window_size[1], C)
    return windows

def window_reverse(windows, window_size, H, W):
    C = windows.shape[-1]
    x = windows.view(-1, H // window_size[0], W // window_size[1], window_size[0], window_size[1], C)
    x = x.permute(0, 1, 3, 2, 4, 5).contiguous().view(-1, H, W, C)
    return x

def get_relative_position_index(win_h: int, win_w: int):
    # get pair-wise relative position index for each token inside the window
    coords = torch.stack(torch.meshgrid(torch.arange(win_h), torch.arange(win_w),indexing='ij'))  # 2, Wh, Ww
    coords_flatten = torch.flatten(coords, 1)  # 2, Wh*Ww
    relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]  # 2, Wh*Ww, Wh*Ww
    relative_coords = relative_coords.permute(1, 2, 0).contiguous()  # Wh*Ww, Wh*Ww, 2
    relative_coords[:, :, 0] += win_h - 1  # shift to start from 0
    relative_coords[:, :, 1] += win_w - 1
    relative_coords[:, :, 0] *= 2 * win_w - 1
    return relative_coords.sum(-1)  # Wh*Ww, Wh*Ww

class WindowAttention(nn.Module):
    def __init__(
            self,
            dim,
            window_size,
    ):
        super().__init__()
        self.window_size = window_size
        self.window_area = self.window_size[0]*self.window_size[1]
        self.num_heads = 4
        head_dim =  dim // self.num_heads
        # attn_dim = head_dim * self.num_heads
        self.scale = head_dim ** -0.5

        self.relative_position_bias_table = nn.Parameter(torch.zeros((2 * window_size[0] - 1) **2, self.num_heads))

        # get pair-wise relative position index for each token inside the window
        self.register_buffer("relative_position_index", get_relative_position_index(self.window_size[0], self.window_size[1]), persistent=False)

        self.qkv = nn.Linear(dim, dim * 3)
        self.proj = nn.Linear(dim, dim)

        torch.nn.init.trunc_normal_(self.relative_position_bias_table, std=.02)
        self.softmax = nn.Softmax(dim=-1)

    def _get_rel_pos_bias(self):
        relative_position_bias = self.relative_position_bias_table[
            self.relative_position_index.view(-1)].view(self.window_area, self.window_area, -1)  # Wh*Ww,Wh*Ww,nH
        relative_position_bias = relative_position_bias.permute(2, 0, 1).contiguous()  # nH, Wh*Ww, Wh*Ww
        return relative_position_bias.unsqueeze(0)

    def forward(self, x, mask = None):
        B_, N, C = x.shape
        qkv = self.qkv(x).reshape(B_, N, 3, self.num_heads, -1).permute(2, 0, 3, 1, 4)
        q, k, v = qkv.unbind(0)


        q = q * self.scale
        attn = q @ k.transpose(-2, -1)
        attn = attn + self._get_rel_pos_bias()
        if mask is not None:
            num_win = mask.shape[0]
            attn = attn.view(-1, num_win, self.num_heads, N, N) + mask.unsqueeze(1).unsqueeze(0)
            attn = attn.view(-1, self.num_heads, N, N)
        attn = self.softmax(attn)
        x = attn @ v

        x = x.transpose(1, 2).reshape(B_, N, -1)
        x = self.proj(x)
        return x

# %%
class SwinTransformerBlock(nn.Module):
    def __init__(
            self,  dim, input_resolution, window_size = 7, shift_size = 0):

        super().__init__()
        self.input_resolution = input_resolution
        window_size = (window_size, window_size)
        shift_size = (shift_size, shift_size)
        self.window_size = window_size
        self.shift_size = shift_size
        self.window_area = self.window_size[0] * self.window_size[1]

        self.norm1 = nn.LayerNorm(dim)
        self.attn = WindowAttention(
            dim,
            window_size=self.window_size,
        )

        self.norm2 = nn.LayerNorm(dim)

        self.mlp = nn.Sequential(
            nn.Linear(dim, 4 * dim),
            nn.GELU(),
            nn.LayerNorm(4 * dim),
            nn.Linear( 4 * dim, dim)
        )

        if self.shift_size:
            # calculate attention mask for SW-MSA
            H, W = self.input_resolution
            H = math.ceil(H / self.window_size[0]) * self.window_size[0]
            W = math.ceil(W / self.window_size[1]) * self.window_size[1]
            img_mask = torch.zeros((1, H, W, 1))  # 1 H W 1
            cnt = 0
            for h in (
                    slice(0, -self.window_size[0]), 
                    slice(-self.window_size[0], -self.shift_size[0]),
                    slice(-self.shift_size[0], None)):
                for w in (
                        slice(0, -self.window_size[1]),
                        slice(-self.window_size[1], -self.shift_size[1]),
                        slice(-self.shift_size[1], None)):
                    img_mask[:, h, w, :] = cnt
                    cnt += 1
            mask_windows = window_partition(img_mask, self.window_size)  # nW, window_size, window_size, 1
            mask_windows = mask_windows.view(-1, self.window_area)
            attn_mask = mask_windows.unsqueeze(1) - mask_windows.unsqueeze(2)
            attn_mask = attn_mask.masked_fill(attn_mask != 0, float(-100.0)).masked_fill(attn_mask == 0, float(0.0))
        else:
            attn_mask = None

        self.register_buffer("attn_mask", attn_mask, persistent=False)

    def _attn(self, x):
        B, H, W, C = x.shape

        # cyclic shift
        if self.shift_size:
            shifted_x = torch.roll(x, shifts=(-self.shift_size[0], -self.shift_size[1]), dims=(1, 2))
        else:
            shifted_x = x

        # partition windows
        x_windows = window_partition(shifted_x, self.window_size)  # nW*B, window_size, window_size, C
        x_windows = x_windows.view(-1, self.window_area, C)  # nW*B, window_size*window_size, C

        # W-MSA/SW-MSA
        attn_windows = self.attn(x_windows, mask=self.attn_mask)  # nW*B, window_size*window_size, C

        # merge windows
        attn_windows = attn_windows.view(-1, self.window_size[0], self.window_size[1], C)
        shifted_x = window_reverse(attn_windows, self.window_size, H, W)  # B H' W' C
        shifted_x = shifted_x[:, :H, :W, :].contiguous()

        # reverse cyclic shift
        if self.shift_size:
            x = torch.roll(shifted_x, shifts=self.shift_size, dims=(1, 2))
        else:
            x = shifted_x
        return x

    def forward(self, x):
        B, H, W, C = x.shape
        B, H, W, C = x.shape
        x = x + self._attn(self.norm1(x))
        x = x.reshape(B, -1, C)
        x = x + self.mlp(self.norm2(x))
        x = x.reshape(B, H,W, C)
        return x

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, in_ch, num_feat, patch_size):
        super().__init__()
        self.conv = nn.Conv2d(in_ch,num_feat, kernel_size=patch_size,
                                  stride=patch_size)

    def forward(self, X):
        # Output shape: (batch size, no. of patches, no. of channels)
        return self.conv(X).permute(0,2,3,1)

class PatchMerging(nn.Module):

    def __init__(
            self,
            dim
    ):
        super().__init__()
        self.norm = nn.LayerNorm(4 * dim)
        self.reduction = nn.Linear(4*dim, 2*dim, bias=False)

    def forward(self, x):
        B, H, W, C = x.shape
        x = x.reshape(B, H // 2, 2, W // 2, 2, C).permute(0, 1, 3, 4, 2, 5).flatten(3)
        x = self.norm(x)
        x = self.reduction(x)
        return x

class PatchExpansion(nn.Module):

    def __init__(
            self,
            dim
    ):
        super().__init__()
        self.norm = nn.LayerNorm(dim//2)
        self.expand = nn.Linear(dim, 2*dim, bias=False)

    def forward(self, x):

        x = self.expand(x)
        B, H, W, C = x.shape

        x = x.view(B, H , W, 2, 2, C//4)
        x = x.permute(0,1,3,2,4,5)

        x = x.reshape(B,H*2, W*2 , C//4)

        x = self.norm(x)
        return x

class FinalPatchExpansion(nn.Module):

    def __init__(
            self,
            dim
    ):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.expand = nn.Linear(dim, 16*dim, bias=False)

    def forward(self, x):

        x = self.expand(x)
        B, H, W, C = x.shape

        x = x.view(B, H , W, 4, 4, C//16)
        x = x.permute(0,1,3,2,4,5)

        x = x.reshape(B,H*4, W*4 , C//16)

        x = self.norm(x)
        return x

# %%
class SwinBlock(nn.Module):
    def __init__(self, dims, ip_res, ss_size = 3):
        super().__init__()
        self.swtb1 = SwinTransformerBlock(dim=dims, input_resolution=ip_res)
        self.swtb2 = SwinTransformerBlock(dim=dims, input_resolution=ip_res, shift_size=ss_size)

    def forward(self, x):
        return self.swtb2(self.swtb1(x))


class Encoder(nn.Module):
    def __init__(self, C, partioned_ip_res, num_blocks=3):
        super().__init__()
        H,W = partioned_ip_res[0], partioned_ip_res[1]
        self.enc_swin_blocks = nn.ModuleList([
            SwinBlock(C, (H, W)),
            SwinBlock(2*C, (H//2, W//2)),
            SwinBlock(4*C, (H//4, W//4))
        ])
        self.enc_patch_merge_blocks = nn.ModuleList([
            PatchMerging(C),
            PatchMerging(2*C),
            PatchMerging(4*C)
        ])

    def forward(self, x):
        skip_conn_ftrs = []
        for swin_block,patch_merger in zip(self.enc_swin_blocks, self.enc_patch_merge_blocks):
            x = swin_block(x)
            skip_conn_ftrs.append(x)
            x = patch_merger(x)
        return x, skip_conn_ftrs


class Decoder(nn.Module):
    def __init__(self, C, partioned_ip_res, num_blocks=3):
        super().__init__()
        H,W = partioned_ip_res[0], partioned_ip_res[1]
        self.dec_swin_blocks = nn.ModuleList([
            SwinBlock(4*C, (H//4, W//4)),
            SwinBlock(2*C, (H//2, W//2)),
            SwinBlock(C, (H, W))
        ])
        self.dec_patch_expand_blocks = nn.ModuleList([
            PatchExpansion(8*C),
            PatchExpansion(4*C),
            PatchExpansion(2*C)
        ])
        self.skip_conn_concat = nn.ModuleList([
            nn.Linear(8*C, 4*C),
            nn.Linear(4*C, 2*C),
            nn.Linear(2*C, 1*C)
        ])

    def forward(self, x, encoder_features):
        for patch_expand,swin_block, enc_ftr, linear_concatter in zip(self.dec_patch_expand_blocks, self.dec_swin_blocks, encoder_features,self.skip_conn_concat):
            x = patch_expand(x)
            x = torch.cat([x, enc_ftr], dim=-1)
            x = linear_concatter(x)
            x = swin_block(x)
        return x


class SwinUNet(nn.Module):
    def __init__(self, H, W, ch, C, num_class, num_blocks=3, patch_size = 4):
        super().__init__()
        self.patch_embed = PatchEmbedding(ch, C, patch_size)
        self.encoder = Encoder(C, (H//patch_size, W//patch_size),num_blocks)
        self.bottleneck = SwinBlock(C*(2**num_blocks), (H//(patch_size* (2**num_blocks)), W//(patch_size* (2**num_blocks))))
        self.decoder = Decoder(C, (H//patch_size, W//patch_size),num_blocks)
        self.final_expansion = FinalPatchExpansion(C)
        self.head        = nn.Conv2d(C, num_class, 1,padding='same')

    def forward(self, x):
        x = self.patch_embed(x)

        x,skip_ftrs  = self.encoder(x)

        x = self.bottleneck(x)

        x = self.decoder(x, skip_ftrs[::-1])

        x = self.final_expansion(x)

        x = self.head(x.permute(0,3,1,2))

        return x

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt

# Directory to save the model weights and plots
SAVE_DIR = "Your Directory"
os.makedirs(SAVE_DIR, exist_ok=True)

def train_epoch(model, dataloader, optimizer, loss_fn, device):
    model.train()
    losses = []
    for x, y in dataloader:
        optimizer.zero_grad()
        out = model(x.to(device))
        loss = loss_fn(out, y.to(device))
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    return np.mean(losses)

def validate_epoch(model, dataloader, loss_fn, device):
    model.eval()
    losses = []
    dice_scores = []
    with torch.no_grad():
        for x, y in dataloader:
            out = model(x.to(device))
            loss = loss_fn(out, y.to(device))
            losses.append(loss.item())
            
            # Calculate Dice coefficient
            pred = (out > 0.5).float()
            intersection = (pred * y.to(device)).sum()
            dice_score = (2. * intersection) / (pred.sum() + y.to(device).sum() + 1e-6)
            dice_scores.append(dice_score.item())
    return np.mean(losses), np.mean(dice_scores)

def plot_metrics(train_losses, val_losses, dice_scores, save_dir):
    # Plot Losses
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
    plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot Dice Coefficient
    plt.subplot(1, 2, 2)
    plt.plot(range(1, len(dice_scores) + 1), dice_scores, label='Dice Coefficient', color='green')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Coefficient')
    plt.title('Validation Dice Coefficient')
    plt.legend()

    plt.tight_layout()

    # Save the plot
    plots_save_path = "your_path"
    plot_path = os.path.join(save_dir, plots_save_path)
    plt.savefig(plot_path)
    print(f"Metrics plot saved to: {plot_path}")
    plt.close()

def train(model, train_loader, valid_loader, optimizer, loss_fn, epochs, min_epochs, early_stop_count, device):
    train_losses = []
    val_losses = []
    dice_scores = []
    best_valid_loss = float('inf')
    EARLY_STOP = early_stop_count

    for ep in range(1, epochs + 1):
        train_loss = train_epoch(model, train_loader, optimizer, loss_fn, device)
        valid_loss, dice_score = validate_epoch(model, valid_loader, loss_fn, device)

        train_losses.append(train_loss)
        val_losses.append(valid_loss)
        dice_scores.append(dice_score)

        print(f"Epoch: {ep}: train_loss={train_loss:.5f}, valid_loss={valid_loss:.5f}, dice_score={dice_score:.5f}")

        # Save model every 10 epochs
        if ep % 10 == 0:
            save_path = os.path.join(SAVE_DIR, f"model_epoch_{ep}.pth")
            torch.save({
                'epoch': ep,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
            }, save_path)
            print(f"Model checkpoint saved at: {save_path}")

        # Save the best model based on validation loss
        if ep > min_epochs:
            if valid_loss < best_valid_loss:
                best_valid_loss = valid_loss
                best_model_path = os.path.join(SAVE_DIR, "best_model.pth")
                torch.save({
                    'epoch': ep,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                }, best_model_path)
                print(f"Best model saved with validation loss {valid_loss:.5f} at epoch {ep}")
                EARLY_STOP = early_stop_count
            else:
                EARLY_STOP -= 1
                if EARLY_STOP <= 0:
                    print("Early stopping triggered.")
                    plot_metrics(train_losses, val_losses, dice_scores, SAVE_DIR)
                    return train_losses, val_losses, dice_scores

    # Save plots after the last epoch
    plot_metrics(train_losses, val_losses, dice_scores, SAVE_DIR)
    return train_losses, val_losses, dice_scores

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(DEVICE)
model = SwinUNet(224,224,1,32,1,3,4).to(DEVICE)

for p in model.parameters():
    if p.dim() > 1:
            nn.init.kaiming_uniform_(p)

optimizer = torch.optim.Adam(model.parameters())
loss_fn = nn.BCEWithLogitsLoss()

# train(model, epochs=40, min_epochs=5, early_stop_count=15)
train(
    model=model,
    train_loader=train_loader,
    valid_loader=valid_loader,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=40,
    min_epochs=5,
    early_stop_count=10,
    device=DEVICE
)
# Out:
# cuda
# Epoch: 1: train_loss=0.05160, valid_loss=0.01685, dice_score=0.92481
# Epoch: 2: train_loss=0.01461, valid_loss=0.01061, dice_score=0.95511
# Epoch: 3: train_loss=0.01101, valid_loss=0.00923, dice_score=0.95489
# Epoch: 4: train_loss=0.01001, valid_loss=0.00860, dice_score=0.95954
# Epoch: 5: train_loss=0.00952, valid_loss=0.00758, dice_score=0.96352
# Epoch: 6: train_loss=0.00814, valid_loss=0.00804, dice_score=0.95843
# Best model saved with validation loss 0.00804 at epoch 6
# Epoch: 7: train_loss=0.00752, valid_loss=0.00712, dice_score=0.96590
# Best model saved with validation loss 0.00712 at epoch 7
# Epoch: 8: train_loss=0.01064, valid_loss=0.00716, dice_score=0.96551
# Epoch: 9: train_loss=0.00793, valid_loss=0.00693, dice_score=0.96526
# Best model saved with validation loss 0.00693 at epoch 9
# Epoch: 10: train_loss=0.00713, valid_loss=0.00655, dice_score=0.96710
# Model checkpoint saved at: F:/weights/swin_unet/p_a/tibia\model_epoch_10.pth
# Best model saved with validation loss 0.00655 at epoch 10
# Epoch: 11: train_loss=0.00867, valid_loss=0.00683, dice_score=0.96904
# Epoch: 12: train_loss=0.00714, valid_loss=0.00656, dice_score=0.96926
# Epoch: 13: train_loss=0.00679, valid_loss=0.00625, dice_score=0.97039
# Best model saved with validation loss 0.00625 at epoch 13
# Epoch: 14: train_loss=0.00787, valid_loss=0.00737, dice_score=0.96551
# Epoch: 15: train_loss=0.00699, valid_loss=0.00627, dice_score=0.97007
# Epoch: 16: train_loss=0.00645, valid_loss=0.00603, dice_score=0.97189
# Best model saved with validation loss 0.00603 at epoch 16
# Epoch: 17: train_loss=0.00641, valid_loss=0.00612, dice_score=0.97080
# Epoch: 18: train_loss=0.00855, valid_loss=0.00671, dice_score=0.96890
# Epoch: 19: train_loss=0.00683, valid_loss=0.00647, dice_score=0.97055
# Epoch: 20: train_loss=0.00633, valid_loss=0.00603, dice_score=0.97023
# Model checkpoint saved at: F:/weights/swin_unet/p_a/tibia\model_epoch_20.pth
# Best model saved with validation loss 0.00603 at epoch 20
# Epoch: 21: train_loss=0.00652, valid_loss=0.00593, dice_score=0.97205
# Best model saved with validation loss 0.00593 at epoch 21
# Epoch: 22: train_loss=0.00609, valid_loss=0.00586, dice_score=0.97213
# Best model saved with validation loss 0.00586 at epoch 22
# Epoch: 23: train_loss=0.00637, valid_loss=0.00603, dice_score=0.97203
# Epoch: 24: train_loss=0.00635, valid_loss=0.00597, dice_score=0.97160
# Epoch: 25: train_loss=0.00583, valid_loss=0.00573, dice_score=0.97225
# Best model saved with validation loss 0.00573 at epoch 25
# Epoch: 26: train_loss=0.00588, valid_loss=0.00567, dice_score=0.97331
# Best model saved with validation loss 0.00567 at epoch 26
# Epoch: 27: train_loss=0.00576, valid_loss=0.00573, dice_score=0.97143
# Epoch: 28: train_loss=0.00936, valid_loss=0.01109, dice_score=0.95021
# Epoch: 29: train_loss=0.00889, valid_loss=0.00697, dice_score=0.96712
# Epoch: 30: train_loss=0.00706, valid_loss=0.00627, dice_score=0.97025
# Model checkpoint saved at: F:/weights/swin_unet/p_a/tibia\model_epoch_30.pth
# Epoch: 31: train_loss=0.00644, valid_loss=0.00643, dice_score=0.97068
# Epoch: 32: train_loss=0.00624, valid_loss=0.00586, dice_score=0.97190
# Epoch: 33: train_loss=0.00598, valid_loss=0.00589, dice_score=0.97172
# Epoch: 34: train_loss=0.00622, valid_loss=0.00589, dice_score=0.97136
# Epoch: 35: train_loss=0.00574, valid_loss=0.00561, dice_score=0.97331
# Best model saved with validation loss 0.00561 at epoch 35
# Epoch: 36: train_loss=0.00565, valid_loss=0.00563, dice_score=0.97310
# Epoch: 37: train_loss=0.00586, valid_loss=0.00542, dice_score=0.97381
# Best model saved with validation loss 0.00542 at epoch 37
# Epoch: 38: train_loss=0.00580, valid_loss=0.00538, dice_score=0.97375
# Best model saved with validation loss 0.00538 at epoch 38
# Epoch: 39: train_loss=0.00543, valid_loss=0.00527, dice_score=0.97367
# Best model saved with validation loss 0.00527 at epoch 39
# Epoch: 40: train_loss=0.00535, valid_loss=0.00540, dice_score=0.97442
# Model checkpoint saved at: F:/weights/swin_unet/p_a/tibia\model_epoch_40.pth
# Metrics plot saved to: F:/models/Swin_unet_plots/prep_aug/Tibia/training_metrics.png
# ([0.05160105866283614,
#   0.01460628815213089,
#   0.011008553792258563,
#   0.010012734761341372,
#   0.009521712564344855,
#   0.008138591661282455,
#   0.007524574359813104,
#   0.010638289091185225,
#   0.00792502654017597,
#   0.0071324287992011615,
#   0.008674001020019768,
#   0.007139048130159583,
#   0.006789812534008443,
#   0.007871893641791883,
#   0.0069861130354456355,
#   0.006453478827972723,
#   0.006411431568258427,
#   0.0085540528541905,
#   0.006829392197842502,
#   0.006333087133663399,
#   0.006520711084607712,
#   0.0060879710367478055,
#   0.006366352120756958,
#   0.006348956030896716,
#   0.005825445937938834,
#   0.005875182807123363,
#   0.0057624743278075945,
#   0.009356871875168598,
#   0.008889656653457596,
#   0.007057560996314677,
#   0.006442793177601844,
#   0.006237804890246143,
#   0.0059755985198562895,
#   0.006218972593210139,
#   0.005740911024310666,
#   0.005651769630132236,
#   0.00586191844875753,
#   0.0058031155031296935,
#   0.005426709747211905,
#   0.0053498632224655545],
#  [0.016850872120509546,
#   0.010611352665970722,
#   0.009227724758804672,
#   0.008595349034294486,
#   0.0075816183169889785,
#   0.008044627365759678,
#   0.007122757210810151,
#   0.007159071845105953,
#   0.006926343582260112,
#   0.006548565307942529,
#   0.006827476615500119,
#   0.0065569316373310154,
#   0.006248266850080755,
#   0.007374463706380791,
#   0.00627495454520815,
#   0.006030750538532932,
#   0.006116102152090106,
#   0.006712433028345306,
#   0.006467194244679477,
#   0.006030057130071024,
#   0.005931039301988979,
#   0.00586171705637955,
#   0.0060255310705138575,
#   0.0059687299136486315,
#   0.005734605740548836,
#   0.005670476885926392,
#   0.005734889716323879,
#   0.01109062355115182,
#   0.00696875949183272,
#   0.006269603178629445,
#   0.006427322902406256,
#   0.00585755526036438,
#   0.005893888863890122,
#   0.005889462785691851,
#   0.005609505822778576,
#   0.005632464476447139,
#   0.005422461713250313,
#   0.005377943575796153,
#   0.005273380898870528,
#   0.005403508031223383],
#  [0.9248105436563492,
#   0.955112819870313,
#   0.9548902726835675,
#   0.959540425075425,
#   0.9635229441854689,
#   0.9584254738357332,
#   0.9659046828746796,
#   0.9655114445421431,
#   0.9652618401580386,
#   0.967103092206849,
#   0.9690392315387726,
#   0.9692556510368983,
#   0.9703919473621581,
#   0.9655142741070853,
#   0.9700662410921521,
#   0.971886427866088,
#   0.9707973301410675,
#   0.9688997798495822,
#   0.9705494443575541,
#   0.9702260692914327,
#   0.9720467180013657,
#   0.9721287935972214,
#   0.9720290783378813,
#   0.9716024150451025,
#   0.972254248128997,
#   0.9733113265699811,
#   0.9714297304550806,
#   0.9502142982350456,
#   0.9671247220701642,
#   0.9702549543645647,
#   0.9706787003411187,
#   0.9718959728876749,
#   0.9717226972182592,
#   0.9713563720385233,
#   0.9733086443609662,
#   0.9731027202473747,
#   0.9738065666622586,
#   0.9737513545486662,
#   0.9736707160870234,
#   0.974416024155087])

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(3,4, figsize=(10,8))
with torch.no_grad():
    for i in range(3):
        x_og,y_og = next(iter(train_loader))
        x = x_og[0]
        y = y_og[0]
        
        ax[i,0].imshow(x.squeeze(0).squeeze(0), cmap='gray')
        ax[i,0].set_title('Image')
        ax[i,1].imshow(y.squeeze(0).squeeze(0), cmap='gray')
        ax[i,1].set_title('Mask')
        x_og = x_og.to(DEVICE)
        out = model(x_og[:1])
        out = nn.Sigmoid()(out)
        out = out.squeeze(0).squeeze(0).cpu()
        ax[i,2].imshow(out, cmap='gray')
        ax[i,2].set_title('Prediction')
        ax[i,3].imshow((out>0.5).float(), cmap='gray')
        ax[i,3].set_title('Threshold Prediction')
plt.show()

# %% [markdown]
# ## Dataset Testing for metrics calculation

# %%
from glob import glob
import numpy as np
from sklearn.model_selection import train_test_split
import cv2
import torch
import torch.nn as nn
import torch.nn.functional
import torchvision
from torch.utils.data import TensorDataset
import math

# %%
def load_image(path, size):
    image = cv2.imread(path)
    image = cv2.resize(image, (size,size))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    image = image/255.
    return image

def load_data(root_path, size):
    images = []
    masks = []
    x = 0
    for path in sorted(glob(root_path)):
        img = load_image(path, size)
        if 'mask' in path:
            if x:
                masks[-1] += img
                masks[-1] = np.array(masks[-1]>0.5, dtype='float64')
            else:
                masks.append(img)
                x = 1
        else:
            images.append(img)
            x = 0
    return np.array(images), np.array(masks)

# %%
import cv2
import numpy as np
from glob import glob
import os

def load_image(path, size):
    image = cv2.imread(path)
    image = cv2.resize(image, (size, size))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    image = image / 255.0
    return image

def load_data(image_folder, mask_folder, size):
    images = []
    masks = []
    
    # Get sorted file lists
    image_paths = sorted(glob(os.path.join(image_folder, '*')))
    mask_paths = sorted(glob(os.path.join(mask_folder, '*')))
    
    for img_path, mask_path in zip(image_paths, mask_paths):
        # Load image
        img = load_image(img_path, size)
        images.append(img)
        
        # Load mask
        mask = load_image(mask_path, size)
        masks.append(mask)
    
    return np.array(images), np.array(masks)

# %%
image_path = "Your designated mask path"
masks_path = "Your designated mask path"

size = 224
# X, Y = load_data('benign_breast ultrasound images/*', size)
X, Y = load_data(image_path, masks_path, size)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, shuffle=True)
X_valid, X_test, Y_valid, Y_test = train_test_split(X_test, Y_test, test_size=0.5,shuffle=True)
X_train.shape, X_valid.shape, X_test.shape, Y_train.shape, Y_valid.shape, Y_test.shape
# Out:
# ((6732, 224, 224),
#  (1443, 224, 224),
#  (1443, 224, 224),
#  (6732, 224, 224),
#  (1443, 224, 224),
#  (1443, 224, 224))

# %%
X_train = np.expand_dims(X_train,-1)
Y_train = np.expand_dims(Y_train,-1)

# Remove transformation functions and transformations
# Simply use the original data as is for training

# No transformations applied
X_train = torch.from_numpy(np.float32(np.squeeze(X_train,-1))).unsqueeze(1)
Y_train = torch.from_numpy(np.float32(np.squeeze(Y_train,-1))).unsqueeze(1)

X_valid = torch.from_numpy(np.float32(X_valid)).unsqueeze(1)
Y_valid = torch.from_numpy(np.float32(Y_valid)).unsqueeze(1)
X_test = torch.from_numpy(np.float32(X_test)).unsqueeze(1)
Y_test = torch.from_numpy(np.float32(Y_test)).unsqueeze(1)

X_train.shape, X_valid.shape, X_test.shape, Y_train.shape, Y_valid.shape, Y_test.shape
# Out:
# (torch.Size([6732, 1, 224, 224]),
#  torch.Size([1443, 1, 224, 224]),
#  torch.Size([1443, 1, 224, 224]),
#  torch.Size([6732, 1, 224, 224]),
#  torch.Size([1443, 1, 224, 224]),
#  torch.Size([1443, 1, 224, 224]))

# %%
BATCH_SIZE = 32

train_loader = torch.utils.data.DataLoader(TensorDataset(X_train,Y_train), batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_loader = torch.utils.data.DataLoader(TensorDataset(X_valid,Y_valid), batch_size=BATCH_SIZE,
                                        shuffle=True)

test_loader = torch.utils.data.DataLoader(TensorDataset(X_test,Y_test), batch_size=BATCH_SIZE,
                                        shuffle=True)

# %% [markdown]
# ## Prediction

# %%
import torch
import torch.nn.functional as F
from sklearn.metrics import jaccard_score, f1_score, accuracy_score
import numpy as np
from collections import OrderedDict
import matplotlib.pyplot as plt
import torch.nn as nn

# Set the device
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")

# Load the state_dict (the checkpoint)

checkpoint = torch.load("Your Checkpoint.pth", map_location=DEVICE)

# Extract the model state_dict
state_dict = checkpoint['model_state_dict'] if 'model_state_dict' in checkpoint else checkpoint

# Remove `module.` prefix if the model was saved using nn.DataParallel
new_state_dict = OrderedDict()
for k, v in state_dict.items():
    if k.startswith("module."):
        new_state_dict[k[7:]] = v  # Remove "module."
    else:
        new_state_dict[k] = v

# Create the model instance (ensure the SwinUNet class is correctly defined)
model = SwinUNet(224, 224, 1, 32, 1, 3, 4).to(DEVICE)

# Load the model state_dict
model.load_state_dict(new_state_dict)

# Move the model to the desired device (GPU or CPU)
model.to(DEVICE)
model.eval()  # Set the model to evaluation mode



# # Initialize and load the model
# model = SwinUNet(224, 224, 1, 32, 1, 3, 4).to(DEVICE)
# model.load_state_dict(new_state_dict)
# model.eval()

# Custom Dataset
class CustomDataset(Dataset):
    def __init__(self, image_folder, mask_folder=None, size=224):
        self.image_paths = sorted(glob(os.path.join(image_folder, '*')))
        self.mask_paths = sorted(glob(os.path.join(mask_folder, '*'))) if mask_folder else None
        self.size = size

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = cv2.imread(img_path)
        image = cv2.resize(image, (self.size, self.size))
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        image = image / 255.0
        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)  # Add channel dimension
        
        if self.mask_paths:
            mask_path = self.mask_paths[idx]
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, (self.size, self.size))
            mask = mask / 255.0
            mask = torch.tensor(mask, dtype=torch.float32).unsqueeze(0)
            return image, mask
        
        return image

# Paths for images and results
image_folder = "Image Folder path"  # Path to 100 test images
output_folder ="Output folder path"  # Path to save segmentation results
os.makedirs(output_folder, exist_ok=True)

# Create DataLoader
test_dataset = CustomDataset(image_folder, size=224)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Evaluation loop
with torch.no_grad():
    for batch_idx, images in enumerate(test_loader):
        images = images.to(DEVICE)
        
        # Get model predictions
        outputs = model(images)
        outputs = nn.Sigmoid()(outputs)  # Apply sigmoid activation
        thresholded_outputs = (outputs > 0.5).float()  # Binarize predictions
        
        # Save the results
        for i in range(images.size(0)):
            output_image = thresholded_outputs[i].cpu().squeeze(0)  # Remove channel dimension
            save_path = os.path.join(output_folder, f"result_{batch_idx * test_loader.batch_size + i}.png")
            save_image(output_image, save_path)

            print(f"Saved: {save_path}")

print("Segmentation results saved successfully!")
# Out:
# Using device: cuda
# C:\Users\assha\AppData\Local\Temp\ipykernel_41176\3002109681.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("F:/weights/swin_unet/np_a/All/best_model.pth", map_location=DEVICE)
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_0.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_1.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_2.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_3.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_4.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_5.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_6.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_7.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_8.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_9.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_10.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_11.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_12.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_13.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_14.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_15.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_16.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_17.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_18.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_19.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_20.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_21.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_22.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_23.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_24.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_25.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_26.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_27.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_28.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_29.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_30.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_31.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_32.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_33.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_34.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_35.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_36.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_37.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_38.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_39.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_40.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_41.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_42.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_43.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_44.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_45.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_46.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_47.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_48.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_49.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_50.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_51.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_52.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_53.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_54.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_55.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_56.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_57.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_58.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_59.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_60.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_61.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_62.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_63.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_64.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_65.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_66.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_67.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_68.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_69.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_70.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_71.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_72.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_73.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_74.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_75.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_76.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_77.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_78.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_79.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_80.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_81.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_82.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_83.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_84.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_85.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_86.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_87.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_88.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_89.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_90.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_91.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_92.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_93.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_94.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_95.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_96.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_97.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_98.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/no_prep/all\result_99.png
# Segmentation results saved successfully!

# %%
import torch
import torch.nn.functional as F
from sklearn.metrics import jaccard_score, f1_score, accuracy_score
import numpy as np
from collections import OrderedDict
import matplotlib.pyplot as plt
import torch.nn as nn

# Set the device
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")

# Load the state_dict (the checkpoint)
# checkpoint = torch.load("F:/weights/swin_unet/np_a/All/best_model.pth", map_location=DEVICE)
checkpoint = torch.load("F:/weights/swin_unet/p_a/all/best_model.pth", map_location=DEVICE)
# checkpoint = torch.load("F:/weights/swin_unet/np_a/All/best_model.pth", map_location=DEVICE)

# Extract the model state_dict
state_dict = checkpoint['model_state_dict'] if 'model_state_dict' in checkpoint else checkpoint

# Remove `module.` prefix if the model was saved using nn.DataParallel
new_state_dict = OrderedDict()
for k, v in state_dict.items():
    if k.startswith("module."):
        new_state_dict[k[7:]] = v  # Remove "module."
    else:
        new_state_dict[k] = v

# Create the model instance (ensure the SwinUNet class is correctly defined)
model = SwinUNet(224, 224, 1, 32, 1, 3, 4).to(DEVICE)

# Load the model state_dict
model.load_state_dict(new_state_dict)

# Move the model to the desired device (GPU or CPU)
model.to(DEVICE)
model.eval()  # Set the model to evaluation mode

# Custom Dataset
class CustomDataset(Dataset):
    def __init__(self, image_folder, size=224):
        self.image_paths = sorted(glob(os.path.join(image_folder, '*')))
        self.size = size

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = cv2.imread(img_path)
        image = cv2.resize(image, (self.size, self.size))
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        image = image / 255.0
        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)  # Add channel dimension
        return image, os.path.basename(img_path)  # Return image and filename

image_folder = "F:/patient_data/bone_data/Testing_all/data_prep/data_all/img"  # Path to 100 test images
output_folder ="F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all"  # Path to save segmentation result
os.makedirs(output_folder, exist_ok=True)

# Create DataLoader
test_dataset = CustomDataset(image_folder, size=224)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Evaluation loop
with torch.no_grad():
    for batch_idx, (images, filenames) in enumerate(test_loader):
        images = images.to(DEVICE)
        
        # Get model predictions
        outputs = model(images)
        outputs = nn.Sigmoid()(outputs)  # Apply sigmoid activation
        thresholded_outputs = (outputs > 0.5).float()  # Binarize predictions
        
        # Save the results using original filenames
        for i in range(images.size(0)):
            output_image = thresholded_outputs[i].cpu().squeeze(0)  # Remove channel dimension
            save_path = os.path.join(output_folder, filenames[i])  # Use original filename
            save_image(output_image, save_path)

            print(f"Saved: {save_path}")

print("Segmentation results saved successfully!")
# Out:
# Using device: cuda
# C:\Users\assha\AppData\Local\Temp\ipykernel_41176\1757816071.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("F:/weights/swin_unet/p_a/all/best_model.pth", map_location=DEVICE)
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000028.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000031.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000038.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000042.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000044.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000081.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000089.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0806 정정화 LT KNEE_00000095.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0819 박외연 LT KNEE_00000032.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0819 박외연 LT KNEE_00000038.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0819 박외연 LT KNEE_00000060.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0819 박외연 LT KNEE_00000070.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0819 박외연 LT KNEE_00000082.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0819 박외연 LT KNEE_00000107.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0819 박외연 LT KNEE_00000111.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000024.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000035.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000045.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000049.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000058.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000059.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000060.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000061.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000068.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000069.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000070.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000080.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000092.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0911 이영희 LT KNEE_00000116.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000035.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000055.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000056.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000076.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000077.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000078.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000079.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000081.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000083.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000092.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000098.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000113.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0923 김경복 LT KNEE_00000120.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000026.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000033.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000037.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000038.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000045.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000048.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000051.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000058.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000062.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000067.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000077.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000079.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000092.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000099.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0925 한재철 LT KNEE_00000113.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000031.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000038.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000041.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000042.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000049.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000060.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000063.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000068.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000069.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000073.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\0930 양순덕 LT KNEE_00000104.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000025.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000040.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000042.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000043.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000070.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000073.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000078.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000082.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000094.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000099.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1001 김정숙 LT KNEE_00000113.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000022.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000034.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000061.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000064.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000066.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000067.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000072.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000078.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000082.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000084.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000106.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1008 천경화 LT KNEE_00000110.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000037.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000052.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000056.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000066.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000071.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000072.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000088.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000089.png
# Saved: F:/patient_data/bone_data/Testing_all/Swin_Unet/prep/all\1010 왕순희 LT KNEE_00000098.png
# Segmentation results saved successfully!
